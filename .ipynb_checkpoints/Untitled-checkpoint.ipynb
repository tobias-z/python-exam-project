# %%
from modules.utils import Nutrition, Cereal
c1 = Cereal("Cornflakes", "Kellogg's", 32.95, 500, Nutrition(7,84,3,0.9,1.13))
c2 = Cereal("Rice Krispies", "Kellogg's", 32.95, 375, Nutrition(6,87,0,1,0))
cereals = [c1, c2]

# %%
import modules.plotting as plot
plot.show_cereal_prices(cereals)
plot.show_prices_per_100g(cereals)
